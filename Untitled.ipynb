# %%
# !pip install dist/blitz_env-0.1.0-py3-none-any.whl
# Out:
# Processing ./dist/blitz_env-0.1.0-py3-none-any.whl
# Requirement already satisfied: pandas==2.1.4 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from blitz-env==0.1.0) (2.1.4)
# Requirement already satisfied: nfl-data-py==0.3.1 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from blitz-env==0.1.0) (0.3.1)
# Requirement already satisfied: protobuf==5.27.4 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from blitz-env==0.1.0) (5.27.4)
# Requirement already satisfied: appdirs>1 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from nfl-data-py==0.3.1->blitz-env==0.1.0) (1.4.4)
# Requirement already satisfied: fastparquet>0.5 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from nfl-data-py==0.3.1->blitz-env==0.1.0) (2024.5.0)
# Requirement already satisfied: python-snappy>0.5 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from nfl-data-py==0.3.1->blitz-env==0.1.0) (0.7.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from pandas==2.1.4->blitz-env==0.1.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from pandas==2.1.4->blitz-env==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from pandas==2.1.4->blitz-env==0.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from pandas==2.1.4->blitz-env==0.1.0) (2024.1)
# Requirement already satisfied: cramjam>=2.3 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from fastparquet>0.5->nfl-data-py==0.3.1->blitz-env==0.1.0) (2.8.3)
# Requirement already satisfied: fsspec in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from fastparquet>0.5->nfl-data-py==0.3.1->blitz-env==0.1.0) (2024.6.1)
# Requirement already satisfied: packaging in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from fastparquet>0.5->nfl-data-py==0.3.1->blitz-env==0.1.0) (24.1)
# Requirement already satisfied: six>=1.5 in /Users/caltonji/opt/anaconda3/envs/botblitz3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.1.4->blitz-env==0.1.0) (1.16.0)
# Installing collected packages: blitz-env
# Successfully installed blitz-env-0.1.0

# %%
from blitz_env import is_drafted, simulate_draft, visualize_draft_board, Player, GameState
from typing import List

def draft_player(game_state: GameState) -> str:
    """
    Selects a player to draft based on the highest rank.

    Args:
        players (List[Player]): A list of Player objects.

    Returns:
        str: The id of the drafted player.
    """
    # Filter out already drafted players
    undrafted_players = [player for player in game_state.players if not is_drafted(player)]
    undrafted_qbs = [player for player in undrafted_players if player.allowed_positions[0] == 'QB']

    # Select the player with the highest rank (lowest rank number)
    if undrafted_qbs:
        drafted_player = min(undrafted_qbs, key=lambda p: p.rank)
        return drafted_player.id
    else:
        return ""  # Return empty string if no undrafted players are available

game_state = simulate_draft(draft_player, 2024)

# %%
visualize_draft_board(game_state)
