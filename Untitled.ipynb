# %%
# !pip install dist/blitz_env-0.1.0-py3-none-any.whl

# %%
from blitz_env import is_drafted, simulate_draft, visualize_draft_board, Player, GameState
from typing import List

def draft_player(game_state: GameState) -> str:
    """
    Selects a player to draft based on the highest rank.

    Args:
        players (List[Player]): A list of Player objects.

    Returns:
        str: The id of the drafted player.
    """
    # Filter out already drafted players
    undrafted_players = [player for player in game_state.players if not is_drafted(player)]
    undrafted_qbs = [player for player in undrafted_players if player.allowed_positions[0] == 'QB']

    # Select the player with the highest rank (lowest rank number)
    if undrafted_qbs:
        drafted_player = min(undrafted_qbs, key=lambda p: p.rank)
        return drafted_player.id
    else:
        return ""  # Return empty string if no undrafted players are available

game_state = simulate_draft(draft_player, 2024)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 25
#      22     else:
#      23         return ""  # Return empty string if no undrafted players are available
# ---> 25 game_state = simulate_draft(draft_player, 2024)
#
# File ~/Documents/Dev/2024/botblitz/blitz_env/simulate_draft.py:128, in simulate_draft(draft_player, year)
#     127 def simulate_draft(draft_player: Callable[[List[Player]], str], year: int):
# --> 128     game_state = init_game_state(year)
#     129     draft_strategy_map = {}
#     131     for team in game_state.teams:
#
# File ~/Documents/Dev/2024/botblitz/blitz_env/simulate_draft.py:70, in init_game_state(year)
#      66 game_state.league_settings.total_rounds = 16
#      67 game_state.league_settings.points_per_reception = 1.0
#      68 game_state.league_settings.slots_per_team.extend(
#      69     [
# ---> 70         init_player_slot(["QB"]),
#      71         init_player_slot(["RB"]),
#      72         init_player_slot(["RB"]),
#      73         init_player_slot(["WR"]),
#      74         init_player_slot(["WR"]),
#      75         init_player_slot(["TE"]),
#      76         init_player_slot(["RB", "WR", "TE"]),
#      77         init_player_slot(["K"]),
#      78         init_player_slot(["DST"]),
#      79         init_player_slot(["Bench"]),
#      80         init_player_slot(["Bench"]),
#      81         init_player_slot(["Bench"]),
#      82         init_player_slot(["Bench"]),
#      83         init_player_slot(["Bench"]),
#      84         init_player_slot(["Bench"]),
#      85     ]
#      86 )
#      87 return game_state
#
# File ~/Documents/Dev/2024/botblitz/blitz_env/simulate_draft.py:22, in init_player_slot(allowed_positions)
#      20 def init_player_slot(allowed_positions: List[str]) -> List[PlayerSlot]:
#      21     player_slot = PlayerSlot()
# ---> 22     player_slot.allowed_player_positions = allowed_positions
#      23     return player_slot
#
# AttributeError: Assignment not allowed to message, map, or repeated field "allowed_player_positions" in protocol message object.

# %%
visualize_draft_board(game_state)
# Out:
# displaying at 0,0
# displaying at 0,2
# displaying at 0,3
# displaying at 0,4
# displaying at 0,5
# displaying at 0,6
# displaying at 0,7
# displaying at 0,8
# displaying at 0,9
# displaying at 1,9
# displaying at 1,8
# displaying at 1,7
# displaying at 1,6
# displaying at 1,5
# displaying at 1,4
# displaying at 1,3
# displaying at 1,2
# displaying at 1,0
# displaying at 0,1
# displaying at 2,0
# displaying at 2,2
# displaying at 1,1
# displaying at 2,3
# displaying at 2,4
# displaying at 2,5
# displaying at 2,6
# displaying at 2,7
# displaying at 2,8
# displaying at 2,9
# displaying at 2,1
# displaying at 3,9
# displaying at 3,8
# displaying at 3,7
# displaying at 3,6
# displaying at 3,5
# displaying at 3,4
# displaying at 3,3
# displaying at 3,2
# displaying at 3,0
# displaying at 4,0
# displaying at 4,2
# displaying at 4,3
# displaying at 4,4
# displaying at 4,5
# displaying at 4,6
# displaying at 4,7
# displaying at 4,8
# displaying at 3,1
# displaying at 4,9
# displaying at 5,9
# displaying at 5,8
# displaying at 5,7
# displaying at 4,1
# displaying at 5,6
# displaying at 5,5
# displaying at 5,4
# displaying at 5,3
# displaying at 5,2
# displaying at 5,0
# displaying at 6,0
# displaying at 5,1
# displaying at 6,2
# displaying at 6,1
# displaying at 6,3
# displaying at 6,4
# displaying at 6,5
# displaying at 6,6
# displaying at 6,7
# displaying at 6,8
# displaying at 6,9
# displaying at 7,9
# displaying at 7,8
# displaying at 7,7
# displaying at 7,6
# displaying at 7,5
# displaying at 7,4
# displaying at 7,3
# displaying at 7,2
# displaying at 7,0
# displaying at 8,0
# displaying at 8,2
# displaying at 8,3
# displaying at 8,4
# displaying at 8,5
# displaying at 8,6
# displaying at 7,1
# displaying at 8,1
# displaying at 8,7
# displaying at 8,8
# displaying at 8,9
# displaying at 9,9
# displaying at 9,8
# displaying at 9,7
# displaying at 9,6
# displaying at 9,5
# displaying at 9,4
# displaying at 9,3
# displaying at 9,2
# displaying at 9,0
# displaying at 10,0
# displaying at 10,2
# displaying at 10,3
# displaying at 10,4
# displaying at 10,5
# displaying at 10,6
# displaying at 9,1
# displaying at 10,1
# displaying at 10,7
# displaying at 10,8
# displaying at 10,9
# displaying at 11,9
# displaying at 11,8
# displaying at 11,7
# displaying at 11,6
# displaying at 11,5
# displaying at 11,4
# displaying at 11,3
# displaying at 11,2
# displaying at 11,0
# displaying at 11,1
# displaying at 12,0
# displaying at 12,2
# displaying at 12,3
# displaying at 12,1
# displaying at 12,4
# displaying at 12,5
# displaying at 12,6
# displaying at 12,7
# displaying at 12,8
# displaying at 12,9
# displaying at 13,9
# displaying at 13,8
# displaying at 13,7
# displaying at 13,6
# displaying at 13,5
# displaying at 13,4
# displaying at 13,3
# displaying at 13,2
# displaying at 13,1
# displaying at 13,0
# displaying at 14,0
# displaying at 14,2
# displaying at 14,3
# displaying at 14,4
# displaying at 14,5
# displaying at 14,6
# displaying at 14,7
# displaying at 14,8
# displaying at 14,9
# displaying at 15,9
# displaying at 15,8
# displaying at 15,7
# displaying at 15,6
# displaying at 15,5
# displaying at 15,4
# displaying at 14,1
# displaying at 15,3
# displaying at 15,2
# displaying at 15,1
# displaying at 15,0

# %%
game_state
# Out:
# players {
#   id: "00-0033280"
#   full_name: "Christian McCaffrey"
#   allowed_positions: "RB"
#   professional_team: "SF"
#   player_bye_week: 1
#   rank: 1
#   tier: 1
#   position_rank: 1
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 1
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0036358"
#   full_name: "CeeDee Lamb"
#   allowed_positions: "WR"
#   professional_team: "DAL"
#   player_bye_week: 1
#   rank: 2
#   tier: 1
#   position_rank: 1
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 2
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0033040"
#   full_name: "Tyreek Hill"
#   allowed_positions: "WR"
#   professional_team: "MIA"
#   player_bye_week: 2
#   rank: 3
#   tier: 1
#   position_rank: 2
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 3
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0036900"
#   full_name: "Ja\'Marr Chase"
#   allowed_positions: "WR"
#   professional_team: "CIN"
#   player_bye_week: 3
#   rank: 4
#   tier: 1
#   position_rank: 3
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 4
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0036963"
#   full_name: "Amon-Ra St. Brown"
#   allowed_positions: "WR"
#   professional_team: "DET"
#   player_bye_week: 4
#   rank: 5
#   tier: 1
#   position_rank: 4
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 5
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038120"
#   full_name: "Breece Hall"
#   allowed_positions: "RB"
#   professional_team: "NYJ"
#   player_bye_week: 2
#   rank: 6
#   tier: 1
#   position_rank: 2
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 7
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0038542"
#   full_name: "Bijan Robinson"
#   allowed_positions: "RB"
#   professional_team: "ATL"
#   player_bye_week: 3
#   rank: 7
#   tier: 1
#   position_rank: 3
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 8
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0036322"
#   full_name: "Justin Jefferson"
#   allowed_positions: "WR"
#   professional_team: "MIN"
#   player_bye_week: 5
#   rank: 8
#   tier: 1
#   position_rank: 5
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 9
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0035676"
#   full_name: "A.J. Brown"
#   allowed_positions: "WR"
#   professional_team: "PHI"
#   player_bye_week: 6
#   rank: 9
#   tier: 2
#   position_rank: 6
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 10
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0037740"
#   full_name: "Garrett Wilson"
#   allowed_positions: "WR"
#   professional_team: "NYJ"
#   player_bye_week: 7
#   rank: 10
#   tier: 2
#   position_rank: 7
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 11
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0039139"
#   full_name: "Jahmyr Gibbs"
#   allowed_positions: "RB"
#   professional_team: "DET"
#   player_bye_week: 4
#   rank: 11
#   tier: 2
#   position_rank: 4
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 12
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0039075"
#   full_name: "Puka Nacua"
#   allowed_positions: "WR"
#   professional_team: "LAR"
#   player_bye_week: 8
#   rank: 12
#   tier: 2
#   position_rank: 8
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 13
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0036223"
#   full_name: "Jonathan Taylor"
#   allowed_positions: "RB"
#   professional_team: "IND"
#   player_bye_week: 5
#   rank: 13
#   tier: 2
#   position_rank: 5
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 14
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Marvin Harrison Jr."
#   allowed_positions: "WR"
#   professional_team: "ARI"
#   player_bye_week: 9
#   rank: 14
#   tier: 2
#   position_rank: 9
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0034844"
#   full_name: "Saquon Barkley"
#   allowed_positions: "RB"
#   professional_team: "PHI"
#   player_bye_week: 6
#   rank: 15
#   tier: 2
#   position_rank: 6
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 17
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0031381"
#   full_name: "Davante Adams"
#   allowed_positions: "WR"
#   professional_team: "LV"
#   player_bye_week: 10
#   rank: 16
#   tier: 2
#   position_rank: 10
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 18
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0037238"
#   full_name: "Drake London"
#   allowed_positions: "WR"
#   professional_team: "ATL"
#   player_bye_week: 11
#   rank: 17
#   tier: 3
#   position_rank: 11
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 19
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0037239"
#   full_name: "Chris Olave"
#   allowed_positions: "WR"
#   professional_team: "NO"
#   player_bye_week: 12
#   rank: 18
#   tier: 3
#   position_rank: 12
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 20
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0034857"
#   full_name: "Josh Allen"
#   allowed_positions: "QB"
#   professional_team: "BUF"
#   player_bye_week: 1
#   rank: 19
#   tier: 3
#   position_rank: 1
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 6
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0036973"
#   full_name: "Travis Etienne Jr."
#   allowed_positions: "RB"
#   professional_team: "JAC"
#   player_bye_week: 7
#   rank: 20
#   tier: 3
#   position_rank: 7
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 21
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0036613"
#   full_name: "Jaylen Waddle"
#   allowed_positions: "WR"
#   professional_team: "MIA"
#   player_bye_week: 13
#   rank: 21
#   tier: 3
#   position_rank: 13
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 22
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0036389"
#   full_name: "Jalen Hurts"
#   allowed_positions: "QB"
#   professional_team: "PHI"
#   player_bye_week: 2
#   rank: 22
#   tier: 3
#   position_rank: 2
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 15
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0036252"
#   full_name: "Michael Pittman Jr."
#   allowed_positions: "WR"
#   professional_team: "IND"
#   player_bye_week: 14
#   rank: 23
#   tier: 3
#   position_rank: 14
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 23
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0031408"
#   full_name: "Mike Evans"
#   allowed_positions: "WR"
#   professional_team: "TB"
#   player_bye_week: 15
#   rank: 24
#   tier: 3
#   position_rank: 15
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 24
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0033908"
#   full_name: "Cooper Kupp"
#   allowed_positions: "WR"
#   professional_team: "LAR"
#   player_bye_week: 16
#   rank: 25
#   tier: 3
#   position_rank: 16
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 25
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036554"
#   full_name: "Nico Collins"
#   allowed_positions: "WR"
#   professional_team: "HOU"
#   player_bye_week: 17
#   rank: 26
#   tier: 3
#   position_rank: 17
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 27
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0039065"
#   full_name: "Sam LaPorta"
#   allowed_positions: "TE"
#   professional_team: "DET"
#   player_bye_week: 1
#   rank: 27
#   tier: 3
#   position_rank: 1
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 28
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0036261"
#   full_name: "Brandon Aiyuk"
#   allowed_positions: "WR"
#   professional_team: "SF"
#   player_bye_week: 18
#   rank: 28
#   tier: 3
#   position_rank: 18
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 29
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0037840"
#   full_name: "Kyren Williams"
#   allowed_positions: "RB"
#   professional_team: "LAR"
#   player_bye_week: 9
#   rank: 29
#   tier: 3
#   position_rank: 9
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 30
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0033873"
#   full_name: "Patrick Mahomes II"
#   allowed_positions: "QB"
#   professional_team: "KC"
#   player_bye_week: 3
#   rank: 30
#   tier: 3
#   position_rank: 3
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 26
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0030506"
#   full_name: "Travis Kelce"
#   allowed_positions: "TE"
#   professional_team: "KC"
#   player_bye_week: 2
#   rank: 31
#   tier: 4
#   position_rank: 2
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 31
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0037197"
#   full_name: "Isiah Pacheco"
#   allowed_positions: "RB"
#   professional_team: "KC"
#   player_bye_week: 8
#   rank: 32
#   tier: 4
#   position_rank: 8
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 32
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0034796"
#   full_name: "Lamar Jackson"
#   allowed_positions: "QB"
#   professional_team: "BAL"
#   player_bye_week: 4
#   rank: 33
#   tier: 4
#   position_rank: 4
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 33
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0035719"
#   full_name: "Deebo Samuel Sr."
#   allowed_positions: "WR"
#   professional_team: "SF"
#   player_bye_week: 19
#   rank: 34
#   tier: 4
#   position_rank: 19
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 34
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0036912"
#   full_name: "DeVonta Smith"
#   allowed_positions: "WR"
#   professional_team: "PHI"
#   player_bye_week: 20
#   rank: 35
#   tier: 4
#   position_rank: 20
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 36
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0039040"
#   full_name: "De\'Von Achane"
#   allowed_positions: "RB"
#   professional_team: "MIA"
#   player_bye_week: 10
#   rank: 36
#   tier: 4
#   position_rank: 10
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 37
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0034827"
#   full_name: "DJ Moore"
#   allowed_positions: "WR"
#   professional_team: "CHI"
#   player_bye_week: 21
#   rank: 37
#   tier: 4
#   position_rank: 21
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 38
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0035640"
#   full_name: "DK Metcalf"
#   allowed_positions: "WR"
#   professional_team: "SEA"
#   player_bye_week: 22
#   rank: 38
#   tier: 4
#   position_rank: 22
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 39
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Malik Nabers"
#   allowed_positions: "WR"
#   professional_team: "NYG"
#   player_bye_week: 23
#   rank: 39
#   tier: 4
#   position_rank: 23
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0032764"
#   full_name: "Derrick Henry"
#   allowed_positions: "RB"
#   professional_team: "BAL"
#   player_bye_week: 11
#   rank: 40
#   tier: 4
#   position_rank: 11
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 40
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0037256"
#   full_name: "Rachaad White"
#   allowed_positions: "RB"
#   professional_team: "TB"
#   player_bye_week: 12
#   rank: 41
#   tier: 4
#   position_rank: 12
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 41
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0033906"
#   full_name: "Alvin Kamara"
#   allowed_positions: "RB"
#   professional_team: "NO"
#   player_bye_week: 13
#   rank: 42
#   tier: 4
#   position_rank: 13
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 42
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0031544"
#   full_name: "Amari Cooper"
#   allowed_positions: "WR"
#   professional_team: "CLE"
#   player_bye_week: 25
#   rank: 43
#   tier: 4
#   position_rank: 25
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 43
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0031588"
#   full_name: "Stefon Diggs"
#   allowed_positions: "WR"
#   professional_team: "HOU"
#   player_bye_week: 24
#   rank: 44
#   tier: 4
#   position_rank: 24
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 44
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0035700"
#   full_name: "Josh Jacobs"
#   allowed_positions: "RB"
#   professional_team: "GB"
#   player_bye_week: 14
#   rank: 45
#   tier: 4
#   position_rank: 14
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 45
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0037248"
#   full_name: "James Cook"
#   allowed_positions: "RB"
#   professional_team: "BUF"
#   player_bye_week: 15
#   rank: 46
#   tier: 5
#   position_rank: 15
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 47
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0037744"
#   full_name: "Trey McBride"
#   allowed_positions: "TE"
#   professional_team: "ARI"
#   player_bye_week: 3
#   rank: 47
#   tier: 5
#   position_rank: 3
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 48
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0039164"
#   full_name: "Anthony Richardson"
#   allowed_positions: "QB"
#   professional_team: "IND"
#   player_bye_week: 6
#   rank: 48
#   tier: 5
#   position_rank: 6
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 35
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0039064"
#   full_name: "Zay Flowers"
#   allowed_positions: "WR"
#   professional_team: "BAL"
#   player_bye_week: 27
#   rank: 49
#   tier: 5
#   position_rank: 27
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 49
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0039067"
#   full_name: "Rashee Rice"
#   allowed_positions: "WR"
#   professional_team: "KC"
#   player_bye_week: 26
#   rank: 50
#   tier: 5
#   position_rank: 26
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 50
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0033897"
#   full_name: "Joe Mixon"
#   allowed_positions: "RB"
#   professional_team: "HOU"
#   player_bye_week: 16
#   rank: 51
#   tier: 5
#   position_rank: 16
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 51
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0036410"
#   full_name: "Tee Higgins"
#   allowed_positions: "WR"
#   professional_team: "CIN"
#   player_bye_week: 29
#   rank: 52
#   tier: 5
#   position_rank: 29
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 52
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0039163"
#   full_name: "C.J. Stroud"
#   allowed_positions: "QB"
#   professional_team: "HOU"
#   player_bye_week: 5
#   rank: 53
#   tier: 5
#   position_rank: 5
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 46
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0035659"
#   full_name: "Terry McLaurin"
#   allowed_positions: "WR"
#   professional_team: "WAS"
#   player_bye_week: 28
#   rank: 54
#   tier: 5
#   position_rank: 28
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 53
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0038134"
#   full_name: "Kenneth Walker III"
#   allowed_positions: "RB"
#   professional_team: "SEA"
#   player_bye_week: 17
#   rank: 55
#   tier: 5
#   position_rank: 17
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 54
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0037247"
#   full_name: "George Pickens"
#   allowed_positions: "WR"
#   professional_team: "PIT"
#   player_bye_week: 30
#   rank: 56
#   tier: 5
#   position_rank: 30
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 56
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0035228"
#   full_name: "Kyler Murray"
#   allowed_positions: "QB"
#   professional_team: "ARI"
#   player_bye_week: 7
#   rank: 57
#   tier: 5
#   position_rank: 7
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 55
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0034775"
#   full_name: "Christian Kirk"
#   allowed_positions: "WR"
#   professional_team: "JAC"
#   player_bye_week: 31
#   rank: 58
#   tier: 5
#   position_rank: 31
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 57
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0034753"
#   full_name: "Mark Andrews"
#   allowed_positions: "TE"
#   professional_team: "BAL"
#   player_bye_week: 4
#   rank: 59
#   tier: 5
#   position_rank: 4
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 58
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0038977"
#   full_name: "Tank Dell"
#   allowed_positions: "WR"
#   professional_team: "HOU"
#   player_bye_week: 32
#   rank: 60
#   tier: 5
#   position_rank: 32
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 59
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0036442"
#   full_name: "Joe Burrow"
#   allowed_positions: "QB"
#   professional_team: "CIN"
#   player_bye_week: 8
#   rank: 61
#   tier: 5
#   position_rank: 8
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 60
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0033921"
#   full_name: "Chris Godwin"
#   allowed_positions: "WR"
#   professional_team: "TB"
#   player_bye_week: 33
#   rank: 62
#   tier: 5
#   position_rank: 33
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 61
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0033077"
#   full_name: "Dak Prescott"
#   allowed_positions: "QB"
#   professional_team: "DAL"
#   player_bye_week: 9
#   rank: 63
#   tier: 5
#   position_rank: 9
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 62
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0038933"
#   full_name: "Dalton Kincaid"
#   allowed_positions: "TE"
#   professional_team: "BUF"
#   player_bye_week: 5
#   rank: 64
#   tier: 5
#   position_rank: 5
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 63
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0033553"
#   full_name: "James Conner"
#   allowed_positions: "RB"
#   professional_team: "ARI"
#   player_bye_week: 18
#   rank: 65
#   tier: 5
#   position_rank: 18
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 64
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0030279"
#   full_name: "Keenan Allen"
#   allowed_positions: "WR"
#   professional_team: "CHI"
#   player_bye_week: 34
#   rank: 66
#   tier: 5
#   position_rank: 34
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 65
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0035216"
#   full_name: "Diontae Johnson"
#   allowed_positions: "WR"
#   professional_team: "CAR"
#   player_bye_week: 35
#   rank: 67
#   tier: 5
#   position_rank: 35
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 67
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0036875"
#   full_name: "Rhamondre Stevenson"
#   allowed_positions: "RB"
#   professional_team: "NE"
#   player_bye_week: 20
#   rank: 68
#   tier: 5
#   position_rank: 20
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 68
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0033293"
#   full_name: "Aaron Jones"
#   allowed_positions: "RB"
#   professional_team: "MIN"
#   player_bye_week: 19
#   rank: 69
#   tier: 5
#   position_rank: 19
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 69
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0036264"
#   full_name: "Jordan Love"
#   allowed_positions: "QB"
#   professional_team: "GB"
#   player_bye_week: 10
#   rank: 70
#   tier: 5
#   position_rank: 10
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 66
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0034837"
#   full_name: "Calvin Ridley"
#   allowed_positions: "WR"
#   professional_team: "TEN"
#   player_bye_week: 36
#   rank: 71
#   tier: 6
#   position_rank: 36
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 70
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0035685"
#   full_name: "David Montgomery"
#   allowed_positions: "RB"
#   professional_team: "DET"
#   player_bye_week: 21
#   rank: 72
#   tier: 6
#   position_rank: 21
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 71
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0036275"
#   full_name: "D\'Andre Swift"
#   allowed_positions: "RB"
#   professional_team: "CHI"
#   player_bye_week: 22
#   rank: 73
#   tier: 6
#   position_rank: 22
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 72
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0036893"
#   full_name: "Najee Harris"
#   allowed_positions: "RB"
#   professional_team: "PIT"
#   player_bye_week: 23
#   rank: 74
#   tier: 6
#   position_rank: 23
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 73
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Jayden Daniels"
#   allowed_positions: "QB"
#   professional_team: "WAS"
#   player_bye_week: 11
#   rank: 75
#   tier: 6
#   position_rank: 11
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0033881"
#   full_name: "Evan Engram"
#   allowed_positions: "TE"
#   professional_team: "JAC"
#   player_bye_week: 6
#   rank: 76
#   tier: 6
#   position_rank: 6
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 74
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0037834"
#   full_name: "Brock Purdy"
#   allowed_positions: "QB"
#   professional_team: "SF"
#   player_bye_week: 12
#   rank: 77
#   tier: 6
#   position_rank: 12
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 75
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0036997"
#   full_name: "Javonte Williams"
#   allowed_positions: "RB"
#   professional_team: "DEN"
#   player_bye_week: 25
#   rank: 78
#   tier: 6
#   position_rank: 25
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 76
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038040"
#   full_name: "Zamir White"
#   allowed_positions: "RB"
#   professional_team: "LV"
#   player_bye_week: 24
#   rank: 79
#   tier: 6
#   position_rank: 24
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 77
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0036970"
#   full_name: "Kyle Pitts"
#   allowed_positions: "TE"
#   professional_team: "ATL"
#   player_bye_week: 7
#   rank: 80
#   tier: 6
#   position_rank: 7
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 78
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0031687"
#   full_name: "Raheem Mostert"
#   allowed_positions: "RB"
#   professional_team: "MIA"
#   player_bye_week: 26
#   rank: 81
#   tier: 6
#   position_rank: 26
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 79
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0039146"
#   full_name: "Jayden Reed"
#   allowed_positions: "WR"
#   professional_team: "GB"
#   player_bye_week: 37
#   rank: 82
#   tier: 6
#   position_rank: 37
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 80
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0038543"
#   full_name: "Jaxon Smith-Njigba"
#   allowed_positions: "WR"
#   professional_team: "SEA"
#   player_bye_week: 38
#   rank: 83
#   tier: 6
#   position_rank: 38
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 81
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0035261"
#   full_name: "Tony Pollard"
#   allowed_positions: "RB"
#   professional_team: "TEN"
#   player_bye_week: 27
#   rank: 84
#   tier: 6
#   position_rank: 27
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 82
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0033288"
#   full_name: "George Kittle"
#   allowed_positions: "TE"
#   professional_team: "SF"
#   player_bye_week: 8
#   rank: 85
#   tier: 6
#   position_rank: 8
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 83
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0036212"
#   full_name: "Tua Tagovailoa"
#   allowed_positions: "QB"
#   professional_team: "MIA"
#   player_bye_week: 13
#   rank: 86
#   tier: 6
#   position_rank: 13
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 84
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Caleb Williams"
#   allowed_positions: "QB"
#   professional_team: "CHI"
#   player_bye_week: 14
#   rank: 87
#   tier: 6
#   position_rank: 14
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0037746"
#   full_name: "Brian Robinson Jr."
#   allowed_positions: "RB"
#   professional_team: "WAS"
#   player_bye_week: 29
#   rank: 88
#   tier: 6
#   position_rank: 29
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 85
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0037228"
#   full_name: "Jaylen Warren"
#   allowed_positions: "RB"
#   professional_team: "PIT"
#   player_bye_week: 28
#   rank: 89
#   tier: 6
#   position_rank: 28
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 87
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0030564"
#   full_name: "DeAndre Hopkins"
#   allowed_positions: "WR"
#   professional_team: "TEN"
#   player_bye_week: 39
#   rank: 90
#   tier: 6
#   position_rank: 39
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 88
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Xavier Worthy"
#   allowed_positions: "WR"
#   professional_team: "KC"
#   player_bye_week: 42
#   rank: 91
#   tier: 6
#   position_rank: 42
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0033106"
#   full_name: "Jared Goff"
#   allowed_positions: "QB"
#   professional_team: "DET"
#   player_bye_week: 15
#   rank: 92
#   tier: 6
#   position_rank: 15
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 86
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0038041"
#   full_name: "Jake Ferguson"
#   allowed_positions: "TE"
#   professional_team: "DAL"
#   player_bye_week: 9
#   rank: 93
#   tier: 6
#   position_rank: 9
#   position_tier: 2
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 89
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0035250"
#   full_name: "Devin Singletary"
#   allowed_positions: "RB"
#   professional_team: "NYG"
#   player_bye_week: 30
#   rank: 94
#   tier: 7
#   position_rank: 30
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 90
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0036971"
#   full_name: "Trevor Lawrence"
#   allowed_positions: "QB"
#   professional_team: "JAC"
#   player_bye_week: 16
#   rank: 95
#   tier: 7
#   position_rank: 16
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 91
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0039032"
#   full_name: "Tyjae Spears"
#   allowed_positions: "RB"
#   professional_team: "TEN"
#   player_bye_week: 31
#   rank: 96
#   tier: 7
#   position_rank: 31
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 92
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Rome Odunze"
#   allowed_positions: "WR"
#   professional_team: "CHI"
#   player_bye_week: 40
#   rank: 97
#   tier: 7
#   position_rank: 40
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0033885"
#   full_name: "David Njoku"
#   allowed_positions: "TE"
#   professional_team: "CLE"
#   player_bye_week: 10
#   rank: 98
#   tier: 7
#   position_rank: 10
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 93
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0034348"
#   full_name: "Courtland Sutton"
#   allowed_positions: "WR"
#   professional_team: "DEN"
#   player_bye_week: 41
#   rank: 99
#   tier: 7
#   position_rank: 41
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 94
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0038124"
#   full_name: "Christian Watson"
#   allowed_positions: "WR"
#   professional_team: "GB"
#   player_bye_week: 43
#   rank: 100
#   tier: 7
#   position_rank: 43
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 96
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038994"
#   full_name: "Jordan Addison"
#   allowed_positions: "WR"
#   professional_team: "MIN"
#   player_bye_week: 46
#   rank: 101
#   tier: 7
#   position_rank: 46
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 97
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Brock Bowers"
#   allowed_positions: "TE"
#   professional_team: "LV"
#   player_bye_week: 11
#   rank: 102
#   tier: 7
#   position_rank: 11
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0035662"
#   full_name: "Marquise Brown"
#   allowed_positions: "WR"
#   professional_team: "KC"
#   player_bye_week: 45
#   rank: 103
#   tier: 7
#   position_rank: 45
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 98
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0034351"
#   full_name: "Dallas Goedert"
#   allowed_positions: "TE"
#   professional_team: "PHI"
#   player_bye_week: 12
#   rank: 104
#   tier: 7
#   position_rank: 12
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 99
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Ladd McConkey"
#   allowed_positions: "WR"
#   professional_team: "LAC"
#   player_bye_week: 44
#   rank: 105
#   tier: 7
#   position_rank: 44
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0029604"
#   full_name: "Kirk Cousins"
#   allowed_positions: "QB"
#   professional_team: "ATL"
#   player_bye_week: 17
#   rank: 106
#   tier: 7
#   position_rank: 17
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 95
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0036355"
#   full_name: "Justin Herbert"
#   allowed_positions: "QB"
#   professional_team: "LAC"
#   player_bye_week: 18
#   rank: 107
#   tier: 7
#   position_rank: 18
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 100
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0033699"
#   full_name: "Austin Ekeler"
#   allowed_positions: "RB"
#   professional_team: "WAS"
#   player_bye_week: 33
#   rank: 108
#   tier: 7
#   position_rank: 33
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 101
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0038597"
#   full_name: "Chase Brown"
#   allowed_positions: "RB"
#   professional_team: "CIN"
#   player_bye_week: 32
#   rank: 109
#   tier: 7
#   position_rank: 32
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 102
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Brian Thomas Jr."
#   allowed_positions: "WR"
#   professional_team: "JAC"
#   player_bye_week: 47
#   rank: 110
#   tier: 7
#   position_rank: 47
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036251"
#   full_name: "Zack Moss"
#   allowed_positions: "RB"
#   professional_team: "CIN"
#   player_bye_week: 34
#   rank: 111
#   tier: 7
#   position_rank: 34
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 103
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0026498"
#   full_name: "Matthew Stafford"
#   allowed_positions: "QB"
#   professional_team: "LAR"
#   player_bye_week: 19
#   rank: 112
#   tier: 7
#   position_rank: 19
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 104
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0032211"
#   full_name: "Tyler Lockett"
#   allowed_positions: "WR"
#   professional_team: "SEA"
#   player_bye_week: 48
#   rank: 113
#   tier: 7
#   position_rank: 48
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 105
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Jonathon Brooks"
#   allowed_positions: "RB"
#   professional_team: "CAR"
#   player_bye_week: 35
#   rank: 114
#   tier: 7
#   position_rank: 35
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0034960"
#   full_name: "Jakobi Meyers"
#   allowed_positions: "WR"
#   professional_team: "LV"
#   player_bye_week: 49
#   rank: 115
#   tier: 7
#   position_rank: 49
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 107
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0036894"
#   full_name: "Pat Freiermuth"
#   allowed_positions: "TE"
#   professional_team: "PIT"
#   player_bye_week: 13
#   rank: 116
#   tier: 7
#   position_rank: 13
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 108
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0037267"
#   full_name: "Jerome Ford"
#   allowed_positions: "RB"
#   professional_team: "CLE"
#   player_bye_week: 36
#   rank: 117
#   tier: 7
#   position_rank: 36
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 109
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0034383"
#   full_name: "Dalton Schultz"
#   allowed_positions: "TE"
#   professional_team: "HOU"
#   player_bye_week: 14
#   rank: 118
#   tier: 7
#   position_rank: 14
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 110
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0037240"
#   full_name: "Jameson Williams"
#   allowed_positions: "WR"
#   professional_team: "DET"
#   player_bye_week: 50
#   rank: 119
#   tier: 7
#   position_rank: 50
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 111
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0023459"
#   full_name: "Aaron Rodgers"
#   allowed_positions: "QB"
#   professional_team: "NYJ"
#   player_bye_week: 20
#   rank: 120
#   tier: 7
#   position_rank: 20
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 106
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0034184"
#   full_name: "Gus Edwards"
#   allowed_positions: "RB"
#   professional_team: "LAC"
#   player_bye_week: 37
#   rank: 121
#   tier: 7
#   position_rank: 37
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 112
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Keon Coleman"
#   allowed_positions: "WR"
#   professional_team: "BUF"
#   player_bye_week: 51
#   rank: 122
#   tier: 7
#   position_rank: 51
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036988"
#   full_name: "Joshua Palmer"
#   allowed_positions: "WR"
#   professional_team: "LAC"
#   player_bye_week: 52
#   rank: 123
#   tier: 7
#   position_rank: 52
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 113
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0033537"
#   full_name: "Deshaun Watson"
#   allowed_positions: "QB"
#   professional_team: "CLE"
#   player_bye_week: 21
#   rank: 124
#   tier: 7
#   position_rank: 21
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 114
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0033045"
#   full_name: "Ezekiel Elliott"
#   allowed_positions: "RB"
#   professional_team: "DAL"
#   player_bye_week: 38
#   rank: 125
#   tier: 7
#   position_rank: 38
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 116
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0037816"
#   full_name: "Romeo Doubs"
#   allowed_positions: "WR"
#   professional_team: "GB"
#   player_bye_week: 53
#   rank: 126
#   tier: 8
#   position_rank: 53
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 117
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0034791"
#   full_name: "Nick Chubb"
#   allowed_positions: "RB"
#   professional_team: "CLE"
#   player_bye_week: 39
#   rank: 127
#   tier: 8
#   position_rank: 39
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 118
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0030565"
#   full_name: "Geno Smith"
#   allowed_positions: "QB"
#   professional_team: "SEA"
#   player_bye_week: 22
#   rank: 128
#   tier: 8
#   position_rank: 22
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 115
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0035229"
#   full_name: "T.J. Hockenson"
#   allowed_positions: "TE"
#   professional_team: "MIN"
#   player_bye_week: 15
#   rank: 129
#   tier: 8
#   position_rank: 15
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 119
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0039165"
#   full_name: "Zach Charbonnet"
#   allowed_positions: "RB"
#   professional_team: "SEA"
#   player_bye_week: 40
#   rank: 130
#   tier: 8
#   position_rank: 40
#   position_tier: 5
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 120
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0033282"
#   full_name: "Curtis Samuel"
#   allowed_positions: "WR"
#   professional_team: "BUF"
#   player_bye_week: 55
#   rank: 131
#   tier: 8
#   position_rank: 55
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 121
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0034855"
#   full_name: "Baker Mayfield"
#   allowed_positions: "QB"
#   professional_team: "TB"
#   player_bye_week: 23
#   rank: 132
#   tier: 8
#   position_rank: 23
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 122
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0037261"
#   full_name: "Khalil Shakir"
#   allowed_positions: "WR"
#   professional_team: "BUF"
#   player_bye_week: 54
#   rank: 133
#   tier: 8
#   position_rank: 54
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 123
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0036555"
#   full_name: "Chuba Hubbard"
#   allowed_positions: "RB"
#   professional_team: "CAR"
#   player_bye_week: 41
#   rank: 134
#   tier: 8
#   position_rank: 41
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 124
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0037545"
#   full_name: "Rashid Shaheed"
#   allowed_positions: "WR"
#   professional_team: "NO"
#   player_bye_week: 56
#   rank: 135
#   tier: 8
#   position_rank: 56
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 125
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0031236"
#   full_name: "Brandin Cooks"
#   allowed_positions: "WR"
#   professional_team: "DAL"
#   player_bye_week: 57
#   rank: 136
#   tier: 8
#   position_rank: 57
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 127
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0033536"
#   full_name: "Mike Williams"
#   allowed_positions: "WR"
#   professional_team: "NYJ"
#   player_bye_week: 58
#   rank: 137
#   tier: 8
#   position_rank: 58
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 128
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "00-0036139"
#   full_name: "Rico Dowdle"
#   allowed_positions: "RB"
#   professional_team: "DAL"
#   player_bye_week: 42
#   rank: 138
#   tier: 8
#   position_rank: 42
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 129
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0039152"
#   full_name: "Will Levis"
#   allowed_positions: "QB"
#   professional_team: "TEN"
#   player_bye_week: 24
#   rank: 139
#   tier: 8
#   position_rank: 24
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 126
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "00-0038997"
#   full_name: "Josh Downs"
#   allowed_positions: "WR"
#   professional_team: "IND"
#   player_bye_week: 59
#   rank: 140
#   tier: 8
#   position_rank: 59
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 130
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "00-0039144"
#   full_name: "Luke Musgrave"
#   allowed_positions: "TE"
#   professional_team: "GB"
#   player_bye_week: 16
#   rank: 141
#   tier: 8
#   position_rank: 16
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 131
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Blake Corum"
#   allowed_positions: "RB"
#   professional_team: "LAR"
#   player_bye_week: 43
#   rank: 142
#   tier: 8
#   position_rank: 43
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036407"
#   full_name: "Jerry Jeudy"
#   allowed_positions: "WR"
#   professional_team: "CLE"
#   player_bye_week: 60
#   rank: 143
#   tier: 8
#   position_rank: 60
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 132
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "00-0036328"
#   full_name: "Antonio Gibson"
#   allowed_positions: "RB"
#   professional_team: "NE"
#   player_bye_week: 45
#   rank: 144
#   tier: 8
#   position_rank: 45
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 133
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Trey Benson"
#   allowed_positions: "RB"
#   professional_team: "ARI"
#   player_bye_week: 49
#   rank: 145
#   tier: 8
#   position_rank: 49
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038794"
#   full_name: "Jaleel McLaughlin"
#   allowed_positions: "RB"
#   professional_team: "DEN"
#   player_bye_week: 44
#   rank: 146
#   tier: 8
#   position_rank: 44
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 134
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0036290"
#   full_name: "Cole Kmet"
#   allowed_positions: "TE"
#   professional_team: "CHI"
#   player_bye_week: 17
#   rank: 147
#   tier: 8
#   position_rank: 17
#   position_tier: 3
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 136
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0037276"
#   full_name: "Ty Chandler"
#   allowed_positions: "RB"
#   professional_team: "MIN"
#   player_bye_week: 46
#   rank: 148
#   tier: 8
#   position_rank: 46
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 137
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0037263"
#   full_name: "Tyler Allgeier"
#   allowed_positions: "RB"
#   professional_team: "ATL"
#   player_bye_week: 47
#   rank: 149
#   tier: 8
#   position_rank: 47
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 138
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0036158"
#   full_name: "J.K. Dobbins"
#   allowed_positions: "RB"
#   professional_team: "LAC"
#   player_bye_week: 48
#   rank: 150
#   tier: 8
#   position_rank: 48
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 139
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0033090"
#   full_name: "Hunter Henry"
#   allowed_positions: "TE"
#   professional_team: "NE"
#   player_bye_week: 19
#   rank: 151
#   tier: 8
#   position_rank: 19
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 140
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0030035"
#   full_name: "Adam Thielen"
#   allowed_positions: "WR"
#   professional_team: "CAR"
#   player_bye_week: 61
#   rank: 152
#   tier: 8
#   position_rank: 61
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 141
#     team_id_chosen: "1"
#   }
# }
# players {
#   id: "00-0036196"
#   full_name: "Gabe Davis"
#   allowed_positions: "WR"
#   professional_team: "JAC"
#   player_bye_week: 62
#   rank: 153
#   tier: 8
#   position_rank: 62
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 142
#     team_id_chosen: "2"
#   }
# }
# players {
#   id: "00-0038393"
#   full_name: "Dontayvion Wicks"
#   allowed_positions: "WR"
#   professional_team: "GB"
#   player_bye_week: 63
#   rank: 154
#   tier: 8
#   position_rank: 63
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 143
#     team_id_chosen: "3"
#   }
# }
# players {
#   id: "00-0034270"
#   full_name: "Tyler Conklin"
#   allowed_positions: "TE"
#   professional_team: "NYJ"
#   player_bye_week: 18
#   rank: 155
#   tier: 8
#   position_rank: 18
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 144
#     team_id_chosen: "4"
#   }
# }
# players {
#   id: "00-0031280"
#   full_name: "Derek Carr"
#   allowed_positions: "QB"
#   professional_team: "NO"
#   player_bye_week: 26
#   rank: 156
#   tier: 8
#   position_rank: 26
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 135
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Baltimore Ravens"
#   allowed_positions: "DST"
#   professional_team: "BAL"
#   player_bye_week: 1
#   rank: 157
#   tier: 8
#   position_rank: 1
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038621"
#   full_name: "DeMario Douglas"
#   allowed_positions: "WR"
#   professional_team: "NE"
#   player_bye_week: 64
#   rank: 158
#   tier: 8
#   position_rank: 64
#   position_tier: 7
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 145
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0035710"
#   full_name: "Daniel Jones"
#   allowed_positions: "QB"
#   professional_team: "NYG"
#   player_bye_week: 25
#   rank: 159
#   tier: 8
#   position_rank: 25
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 146
#     team_id_chosen: "6"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Ray Davis"
#   allowed_positions: "RB"
#   professional_team: "BUF"
#   player_bye_week: 51
#   rank: 160
#   tier: 9
#   position_rank: 51
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036309"
#   full_name: "Darnell Mooney"
#   allowed_positions: "WR"
#   professional_team: "ATL"
#   player_bye_week: 67
#   rank: 161
#   tier: 9
#   position_rank: 67
#   position_tier: 7
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 147
#     team_id_chosen: "7"
#   }
# }
# players {
#   id: "00-0036906"
#   full_name: "Khalil Herbert"
#   allowed_positions: "RB"
#   professional_team: "CHI"
#   player_bye_week: 50
#   rank: 162
#   tier: 9
#   position_rank: 50
#   position_tier: 6
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 148
#     team_id_chosen: "8"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Adonai Mitchell"
#   allowed_positions: "WR"
#   professional_team: "IND"
#   player_bye_week: 65
#   rank: 163
#   tier: 9
#   position_rank: 65
#   position_tier: 7
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038559"
#   full_name: "Michael Wilson"
#   allowed_positions: "WR"
#   professional_team: "ARI"
#   player_bye_week: 68
#   rank: 164
#   tier: 9
#   position_rank: 68
#   position_tier: 7
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 149
#     team_id_chosen: "9"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Ja\'Lynn Polk"
#   allowed_positions: "WR"
#   professional_team: "NE"
#   player_bye_week: 66
#   rank: 165
#   tier: 9
#   position_rank: 66
#   position_tier: 7
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "nan"
#   full_name: "San Francisco 49ers"
#   allowed_positions: "DST"
#   professional_team: "SF"
#   player_bye_week: 3
#   rank: 166
#   tier: 9
#   position_rank: 3
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0039150"
#   full_name: "Bryce Young"
#   allowed_positions: "QB"
#   professional_team: "CAR"
#   player_bye_week: 27
#   rank: 167
#   tier: 9
#   position_rank: 27
#   position_tier: 4
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 150
#     team_id_chosen: "10"
#   }
# }
# players {
#   id: "nan"
#   full_name: "New York Jets"
#   allowed_positions: "DST"
#   professional_team: "NYJ"
#   player_bye_week: 2
#   rank: 168
#   tier: 9
#   position_rank: 2
#   position_tier: 1
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038129"
#   full_name: "Cade Otton"
#   allowed_positions: "TE"
# ...
#   position_tier: 10
# }
# players {
#   id: "00-0038935"
#   full_name: "Brenton Strange"
#   allowed_positions: "TE"
#   professional_team: "JAC"
#   player_bye_week: 80
#   rank: 513
#   tier: 14
#   position_rank: 80
#   position_tier: 8
# }
# players {
#   id: "00-0031345"
#   full_name: "Jimmy Garoppolo"
#   allowed_positions: "QB"
#   professional_team: "LAR"
#   player_bye_week: 50
#   rank: 514
#   tier: 14
#   position_rank: 50
#   position_tier: 6
# }
# players {
#   id: "nan"
#   full_name: "Anthony Gould"
#   allowed_positions: "WR"
#   professional_team: "IND"
#   player_bye_week: 169
#   rank: 515
#   tier: 14
#   position_rank: 169
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0032385"
#   full_name: "Sterling Shepard"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 184
#   rank: 516
#   tier: 14
#   position_rank: 184
#   position_tier: 11
# }
# players {
#   id: "00-0037617"
#   full_name: "Hassan Haskins"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 141
#   rank: 517
#   tier: 14
#   position_rank: 141
#   position_tier: 10
# }
# players {
#   id: "00-0036628"
#   full_name: "John Bates"
#   allowed_positions: "TE"
#   professional_team: "WAS"
#   player_bye_week: 82
#   rank: 518
#   tier: 14
#   position_rank: 82
#   position_tier: 8
# }
# players {
#   id: "00-0034816"
#   full_name: "Ronald Jones II"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 171
#   rank: 519
#   tier: 14
#   position_rank: 171
#   position_tier: 11
# }
# players {
#   id: "00-0037012"
#   full_name: "Trey Lance"
#   allowed_positions: "QB"
#   professional_team: "DAL"
#   player_bye_week: 62
#   rank: 520
#   tier: 14
#   position_rank: 62
#   position_tier: 7
# }
# players {
#   id: "nan"
#   full_name: "Devaughn Vele"
#   allowed_positions: "WR"
#   professional_team: "DEN"
#   player_bye_week: 186
#   rank: 521
#   tier: 14
#   position_rank: 186
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0029293"
#   full_name: "Marvin Jones Jr."
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 239
#   rank: 522
#   tier: 14
#   position_rank: 239
#   position_tier: 12
# }
# players {
#   id: "00-0035282"
#   full_name: "Easton Stick"
#   allowed_positions: "QB"
#   professional_team: "LAC"
#   player_bye_week: 55
#   rank: 523
#   tier: 14
#   position_rank: 55
#   position_tier: 6
# }
# players {
#   id: "00-0035973"
#   full_name: "Patrick Taylor Jr."
#   allowed_positions: "RB"
#   professional_team: "SF"
#   player_bye_week: 151
#   rank: 524
#   tier: 14
#   position_rank: 151
#   position_tier: 11
# }
# players {
#   id: "nan"
#   full_name: "Joe Milton III"
#   allowed_positions: "QB"
#   professional_team: "NE"
#   player_bye_week: 79
#   rank: 525
#   tier: 14
#   position_rank: 79
#   position_tier: 8
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Chris Brooks"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 148
#   rank: 526
#   tier: 14
#   position_rank: 148
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036816"
#   full_name: "Riley Patterson"
#   allowed_positions: "K"
#   professional_team: "FA"
#   player_bye_week: 36
#   rank: 527
#   tier: 14
#   position_rank: 36
#   position_tier: 5
# }
# players {
#   id: "00-0031595"
#   full_name: "Michael Burton"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 143
#   rank: 528
#   tier: 14
#   position_rank: 143
#   position_tier: 10
# }
# players {
#   id: "00-0035414"
#   full_name: "Jalen Guyton"
#   allowed_positions: "WR"
#   professional_team: "LV"
#   player_bye_week: 173
#   rank: 529
#   tier: 14
#   position_rank: 173
#   position_tier: 11
# }
# players {
#   id: "00-0034771"
#   full_name: "Mason Rudolph"
#   allowed_positions: "QB"
#   professional_team: "TEN"
#   player_bye_week: 61
#   rank: 530
#   tier: 14
#   position_rank: 61
#   position_tier: 7
# }
# players {
#   id: "00-0025565"
#   full_name: "Nick Folk"
#   allowed_positions: "K"
#   professional_team: "TEN"
#   player_bye_week: 29
#   rank: 531
#   tier: 14
#   position_rank: 29
#   position_tier: 4
# }
# players {
#   id: "nan"
#   full_name: "George Holani"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 140
#   rank: 532
#   tier: 15
#   position_rank: 140
#   position_tier: 10
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038476"
#   full_name: "Tommy DeVito"
#   allowed_positions: "QB"
#   professional_team: "NYG"
#   player_bye_week: 67
#   rank: 533
#   tier: 15
#   position_rank: 67
#   position_tier: 7
# }
# players {
#   id: "00-0035831"
#   full_name: "James Robinson"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 161
#   rank: 534
#   tier: 15
#   position_rank: 161
#   position_tier: 11
# }
# players {
#   id: "00-0038409"
#   full_name: "Lew Nichols III"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 168
#   rank: 535
#   tier: 15
#   position_rank: 168
#   position_tier: 11
# }
# players {
#   id: "nan"
#   full_name: "Jha\'Quan Jackson"
#   allowed_positions: "WR"
#   professional_team: "TEN"
#   player_bye_week: 176
#   rank: 536
#   tier: 15
#   position_rank: 176
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0039050"
#   full_name: "Payne Durham"
#   allowed_positions: "TE"
#   professional_team: "TB"
#   player_bye_week: 85
#   rank: 537
#   tier: 15
#   position_rank: 85
#   position_tier: 8
# }
# players {
#   id: "00-0038738"
#   full_name: "Hunter Luepke"
#   allowed_positions: "RB"
#   professional_team: "DAL"
#   player_bye_week: 139
#   rank: 538
#   tier: 15
#   position_rank: 139
#   position_tier: 10
# }
# players {
#   id: "nan"
#   full_name: "Dallin Holker"
#   allowed_positions: "TE"
#   professional_team: "NO"
#   player_bye_week: 91
#   rank: 539
#   tier: 15
#   position_rank: 91
#   position_tier: 8
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0036527"
#   full_name: "DJ Turner"
#   allowed_positions: "WR"
#   professional_team: "LV"
#   player_bye_week: 202
#   rank: 540
#   tier: 15
#   position_rank: 202
#   position_tier: 12
# }
# players {
#   id: "00-0036950"
#   full_name: "Avery Williams"
#   allowed_positions: "RB"
#   professional_team: "ATL"
#   player_bye_week: 133
#   rank: 541
#   tier: 15
#   position_rank: 133
#   position_tier: 10
# }
# players {
#   id: "00-0036412"
#   full_name: "KJ Hamler"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 204
#   rank: 542
#   tier: 15
#   position_rank: 204
#   position_tier: 12
# }
# players {
#   id: "00-0038720"
#   full_name: "Julian Hill"
#   allowed_positions: "TE"
#   professional_team: "MIA"
#   player_bye_week: 101
#   rank: 543
#   tier: 15
#   position_rank: 101
#   position_tier: 9
# }
# players {
#   id: "00-0037827"
#   full_name: "Tyrion Davis-Price"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 170
#   rank: 544
#   tier: 15
#   position_rank: 170
#   position_tier: 11
# }
# players {
#   id: "nan"
#   full_name: "Michael Wiley"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 160
#   rank: 545
#   tier: 15
#   position_rank: 160
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "nan"
#   full_name: "Cornelius Johnson"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 189
#   rank: 546
#   tier: 15
#   position_rank: 189
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0035993"
#   full_name: "Tyler Huntley"
#   allowed_positions: "QB"
#   professional_team: "CLE"
#   player_bye_week: 71
#   rank: 547
#   tier: 15
#   position_rank: 71
#   position_tier: 7
# }
# players {
#   id: "nan"
#   full_name: "Isaiah Williams"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 205
#   rank: 548
#   tier: 15
#   position_rank: 205
#   position_tier: 12
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0038492"
#   full_name: "Jason Brownlee"
#   allowed_positions: "WR"
#   professional_team: "NYJ"
#   player_bye_week: 177
#   rank: 549
#   tier: 15
#   position_rank: 177
#   position_tier: 11
# }
# players {
#   id: "nan"
#   full_name: "Dante Miller"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 147
#   rank: 550
#   tier: 15
#   position_rank: 147
#   position_tier: 11
#   draft_status {
#     availability: DRAFTED
#     pick_chosen: 16
#     team_id_chosen: "5"
#   }
# }
# players {
#   id: "00-0037569"
#   full_name: "Peyton Hendershot"
#   allowed_positions: "TE"
#   professional_team: "KC"
#   player_bye_week: 86
#   rank: 551
#   tier: 15
#   position_rank: 86
#   position_tier: 8
# }
# players {
#   id: "00-0038406"
#   full_name: "Zack Kuntz"
#   allowed_positions: "TE"
#   professional_team: "FA"
#   player_bye_week: 96
#   rank: 552
#   tier: 15
#   position_rank: 96
#   position_tier: 9
# }
# players {
#   id: "00-0031763"
#   full_name: "DeAndre Carter"
#   allowed_positions: "WR"
#   professional_team: "CHI"
#   player_bye_week: 207
#   rank: 553
#   tier: 15
#   position_rank: 207
#   position_tier: 12
# }
# players {
#   id: "00-0033251"
#   full_name: "Zach Pascal"
#   allowed_positions: "WR"
#   professional_team: "ARI"
#   player_bye_week: 183
#   rank: 554
#   tier: 15
#   position_rank: 183
#   position_tier: 11
# }
# players {
#   id: "00-0036887"
#   full_name: "Luke Farrell"
#   allowed_positions: "TE"
#   professional_team: "JAC"
#   player_bye_week: 81
#   rank: 555
#   tier: 15
#   position_rank: 81
#   position_tier: 8
# }
# players {
#   id: "00-0033662"
#   full_name: "Cooper Rush"
#   allowed_positions: "QB"
#   professional_team: "DAL"
#   player_bye_week: 64
#   rank: 556
#   tier: 15
#   position_rank: 64
#   position_tier: 7
# }
# players {
#   id: "00-0036741"
#   full_name: "Jack Stoll"
#   allowed_positions: "TE"
#   professional_team: "FA"
#   player_bye_week: 109
#   rank: 557
#   tier: 15
#   position_rank: 109
#   position_tier: 9
# }
# players {
#   id: "00-0037487"
#   full_name: "Deven Thompkins"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 224
#   rank: 558
#   tier: 15
#   position_rank: 224
#   position_tier: 12
# }
# players {
#   id: "00-0038821"
#   full_name: "Rakim Jarrett"
#   allowed_positions: "WR"
#   professional_team: "TB"
#   player_bye_week: 181
#   rank: 559
#   tier: 15
#   position_rank: 181
#   position_tier: 11
# }
# players {
#   id: "00-0036427"
#   full_name: "Tyler Johnson"
#   allowed_positions: "WR"
#   professional_team: "LAR"
#   player_bye_week: 208
#   rank: 560
#   tier: 15
#   position_rank: 208
#   position_tier: 12
# }
# players {
#   id: "00-0036438"
#   full_name: "Stephen Sullivan"
#   allowed_positions: "TE"
#   professional_team: "FA"
#   player_bye_week: 112
#   rank: 561
#   tier: 15
#   position_rank: 112
#   position_tier: 9
# }
# players {
#   id: "00-0036423"
#   full_name: "Albert Okwuegbunam Jr."
#   allowed_positions: "TE"
#   professional_team: "PHI"
#   player_bye_week: 93
#   rank: 562
#   tier: 15
#   position_rank: 93
#   position_tier: 8
# }
# players {
#   id: "00-0038416"
#   full_name: "Tyson Bagent"
#   allowed_positions: "QB"
#   professional_team: "CHI"
#   player_bye_week: 57
#   rank: 563
#   tier: 15
#   position_rank: 57
#   position_tier: 7
# }
# players {
#   id: "00-0038598"
#   full_name: "Jaren Hall"
#   allowed_positions: "QB"
#   professional_team: "MIN"
#   player_bye_week: 66
#   rank: 564
#   tier: 15
#   position_rank: 66
#   position_tier: 7
# }
# players {
#   id: "00-0036463"
#   full_name: "Chris Blair"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 190
#   rank: 565
#   tier: 15
#   position_rank: 190
#   position_tier: 11
# }
# players {
#   id: "00-0037004"
#   full_name: "Hunter Long"
#   allowed_positions: "TE"
#   professional_team: "LAR"
#   player_bye_week: 98
#   rank: 566
#   tier: 15
#   position_rank: 98
#   position_tier: 9
# }
# players {
#   id: "00-0032128"
#   full_name: "Chris Conley"
#   allowed_positions: "WR"
#   professional_team: "SF"
#   player_bye_week: 214
#   rank: 567
#   tier: 15
#   position_rank: 214
#   position_tier: 12
# }
# players {
#   id: "00-0036187"
#   full_name: "Reggie Gilliam"
#   allowed_positions: "RB"
#   professional_team: "BUF"
#   player_bye_week: 153
#   rank: 568
#   tier: 15
#   position_rank: 153
#   position_tier: 11
# }
# players {
#   id: "00-0035311"
#   full_name: "Myles Gaskin"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 144
#   rank: 569
#   tier: 15
#   position_rank: 144
#   position_tier: 10
# }
# players {
#   id: "00-0038458"
#   full_name: "Owen Wright"
#   allowed_positions: "RB"
#   professional_team: "BAL"
#   player_bye_week: 154
#   rank: 570
#   tier: 15
#   position_rank: 154
#   position_tier: 11
# }
# players {
#   id: "00-0033589"
#   full_name: "David Moore"
#   allowed_positions: "WR"
#   professional_team: "CAR"
#   player_bye_week: 194
#   rank: 571
#   tier: 15
#   position_rank: 194
#   position_tier: 11
# }
# players {
#   id: "00-0037098"
#   full_name: "Samori Toure"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 180
#   rank: 572
#   tier: 15
#   position_rank: 180
#   position_tier: 11
# }
# players {
#   id: "00-0038647"
#   full_name: "Ronnie Bell"
#   allowed_positions: "WR"
#   professional_team: "SF"
#   player_bye_week: 195
#   rank: 573
#   tier: 15
#   position_rank: 195
#   position_tier: 11
# }
# players {
#   id: "00-0034279"
#   full_name: "Equanimeous St. Brown"
#   allowed_positions: "WR"
#   professional_team: "FA"
#   player_bye_week: 192
#   rank: 574
#   tier: 15
#   position_rank: 192
#   position_tier: 11
# }
# players {
#   id: "00-0036387"
#   full_name: "Jalen Reagor"
#   allowed_positions: "WR"
#   professional_team: "NE"
#   player_bye_week: 179
#   rank: 575
#   tier: 15
#   position_rank: 179
#   position_tier: 11
# }
# players {
#   id: "00-0036999"
#   full_name: "Anthony Schwartz"
#   allowed_positions: "WR"
#   professional_team: "MIA"
#   player_bye_week: 266
#   rank: 576
#   tier: 15
#   position_rank: 266
#   position_tier: 13
# }
# players {
#   id: "00-0037745"
#   full_name: "Velus Jones Jr."
#   allowed_positions: "WR"
#   professional_team: "CHI"
#   player_bye_week: 178
#   rank: 577
#   tier: 15
#   position_rank: 178
#   position_tier: 11
# }
# players {
#   id: "00-0036646"
#   full_name: "Simi Fehoko"
#   allowed_positions: "WR"
#   professional_team: "LAC"
#   player_bye_week: 197
#   rank: 578
#   tier: 15
#   position_rank: 197
#   position_tier: 11
# }
# players {
#   id: "00-0034401"
#   full_name: "Mike White"
#   allowed_positions: "QB"
#   professional_team: "FA"
#   player_bye_week: 63
#   rank: 579
#   tier: 15
#   position_rank: 63
#   position_tier: 7
# }
# players {
#   id: "00-0038550"
#   full_name: "Hendon Hooker"
#   allowed_positions: "QB"
#   professional_team: "DET"
#   player_bye_week: 59
#   rank: 580
#   tier: 15
#   position_rank: 59
#   position_tier: 7
# }
# players {
#   id: "00-0034073"
#   full_name: "Ross Dwelley"
#   allowed_positions: "TE"
#   professional_team: "ATL"
#   player_bye_week: 94
#   rank: 581
#   tier: 15
#   position_rank: 94
#   position_tier: 9
# }
# players {
#   id: "00-0038046"
#   full_name: "Charlie Kolar"
#   allowed_positions: "TE"
#   professional_team: "BAL"
#   player_bye_week: 90
#   rank: 582
#   tier: 15
#   position_rank: 90
#   position_tier: 8
# }
# players {
#   id: "00-0034253"
#   full_name: "Dontrell Hilliard"
#   allowed_positions: "RB"
#   professional_team: "FA"
#   player_bye_week: 183
#   rank: 583
#   tier: 15
#   position_rank: 183
#   position_tier: 11
# }
# players {
#   id: "00-0035298"
#   full_name: "Scotty Miller"
#   allowed_positions: "WR"
#   professional_team: "PIT"
#   player_bye_week: 174
#   rank: 584
#   tier: 15
#   position_rank: 174
#   position_tier: 11
# }
# players {
#   id: "00-0029701"
#   full_name: "Ryan Tannehill"
#   allowed_positions: "QB"
#   professional_team: "FA"
#   player_bye_week: 83
#   rank: 585
#   tier: 15
#   position_rank: 83
#   position_tier: 8
# }
# teams {
#   id: "1"
#   name: "A"
#   owner: "Alex"
# }
# teams {
#   id: "2"
#   name: "B"
#   owner: "Ben"
# }
# teams {
#   id: "3"
#   name: "C"
#   owner: "Chris"
# }
# teams {
#   id: "4"
#   name: "D"
#   owner: "Drew"
# }
# teams {
#   id: "5"
#   name: "E"
#   owner: "Elizabeth"
# }
# teams {
#   id: "6"
#   name: "Your Bot"
#   owner: "User"
# }
# teams {
#   id: "7"
#   name: "G"
#   owner: "Gillian"
# }
# teams {
#   id: "8"
#   name: "H"
#   owner: "Harry"
# }
# teams {
#   id: "9"
#   name: "J"
#   owner: "Jon"
# }
# teams {
#   id: "10"
#   name: "K"
#   owner: "Kevin"
# }
# current_pick: 161
# total_rounds: 16
# drafting_team_id: "1"
